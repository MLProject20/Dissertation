# %%
import pandas as pd
import numpy as np
import os
import glob as gb

# %%
path = 'C:\\Users\\padu\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA'
os.chdir(path)

# %%
All = gb.glob(path + "/*.csv")
All
# Out:
# ['C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\MedianAge2013.csv',
#  'C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\MedianAge2014.csv',
#  'C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\MedianAge2015.csv',
#  'C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\MedianAge2016.csv',
#  'C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\MedianAge2017.csv',
#  'C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\MedianAge2018.csv',
#  'C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\MedianAge2019.csv',
#  'C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\MedianAge2020.csv',
# ...

# %%
results = []
for row in All:
    left = pd.read_csv(row)
    print(row)
    print(left.shape)
# Out:
# C:\Users\padu\Dropbox (UNC Charlotte)\Providence Adu’s files\Data\US Census Bureau NPA\MedianAge2013.csv
# (462, 2)
# C:\Users\padu\Dropbox (UNC Charlotte)\Providence Adu’s files\Data\US Census Bureau NPA\MedianAge2014.csv
# (462, 2)
# C:\Users\padu\Dropbox (UNC Charlotte)\Providence Adu’s files\Data\US Census Bureau NPA\MedianAge2015.csv
# (462, 2)
# C:\Users\padu\Dropbox (UNC Charlotte)\Providence Adu’s files\Data\US Census Bureau NPA\MedianAge2016.csv
# (462, 2)
# C:\Users\padu\Dropbox (UNC Charlotte)\Providence Adu’s files\Data\US Census Bureau NPA\MedianAge2017.csv
# (462, 2)
# C:\Users\padu\Dropbox (UNC Charlotte)\Providence Adu’s files\Data\US Census Bureau NPA\MedianAge2018.csv
# (462, 2)
# C:\Users\padu\Dropbox (UNC Charlotte)\Providence Adu’s files\Data\US Census Bureau NPA\MedianAge2019.csv
# (462, 2)
# C:\Users\padu\Dropbox (UNC Charlotte)\Providence Adu’s files\Data\US Census Bureau NPA\MedianAge2020.csv
# (462, 2)
# ...

# %%
right = pd.read_csv('C:\\Users\\padu\\Dropbox (UNC Charlotte)\\Providence Adu’s files\\Data\\US Census Bureau NPA\\NPAHousingUnitsCodeViolations.csv')
right
# Out:
#      NPA  HousingUnits2022  HousingUnits2020  HousingUnits2019  \
# 0      2               744               726               726
# 1      3              3665              3588              3588
# 2      4               425               425               425
# 3      5               209               204               204
# 4      6               698               674               674
# ..   ...               ...               ...               ...
# 457  471               853               840               840
# 458  472               609               579               579
# 459  473               966               941               941
# 460  474               943               892               892
# 461  475               955               817               817
#
#      HousingUnits2018  HousingUnits2017  HousingUnits2016  HousingUnits2015  \
# 0                 731               733               731               715
# ...

# %%
results = [pd.read_csv(csv) for csv in All]

# %%
results
# Out:
# [     NPA  MSAge2013
#  0      2       35.0
#  1      3       34.0
#  2      4       43.6
#  3      5       35.1
#  4      6       38.0
#  ..   ...        ...
#  457  471       35.1
#  458  472       47.7
#  459  473       38.0
#  460  474       40.5
#  461  475       41.1
#
#  [462 rows x 2 columns],
#       NPA  MSAge2014
#  0      2       38.0
#  1      3       35.0
#  2      4       44.4
#  3      5       24.7
#  4      6       39.0
#  ..   ...        ...
#  457  471       33.7
#  458  472       45.7
#  459  473       37.1
#  460  474       38.4
#  461  475       44.3
#
#  [462 rows x 2 columns],
#       NPA  MSAge2015
#  0      2       37.0
#  1      3       35.0
#  2      4       46.8
#  3      5       32.8
#  4      6       43.0
#  ..   ...        ...
#  457  471       33.7
#  458  472       45.8
#  459  473       37.0
#  460  474       41.0
#  461  475       46.2
#
#  [462 rows x 2 columns],
#       NPA  MSAge2016
#  0      2       35.0
#  1      3       36.0
# ...

# %%
from functools import reduce

# %%
data = reduce(lambda right, left: pd.merge(right,left, on='NPA'), results)

# %%
data.shape
# Out:
# (457, 111)

# %%
data.to_csv('AllVariables.csv')
